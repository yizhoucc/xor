# %%
import argparse
import torch
import torch.nn as nn
from model import DenseLayerWithComplexNeurons, Conv2dLayerWithComplexNeurons

arity=2

# %%
inner_net_1 = nn.Sequential(
    nn.Conv2d(arity, 10, 1),
    nn.ReLU(),
    nn.Conv2d(10, 10, 1),
    nn.ReLU(),
    nn.Conv2d(10, 1, 1)
)

inner_net_2 = nn.Sequential(
    nn.Conv2d(arity, 10, 1),
    nn.ReLU(),
    nn.Conv2d(10, 10, 1),
    nn.ReLU(),
    nn.Conv2d(10, 1, 1)
)

inner_net_3 = nn.Sequential(
    nn.Conv2d(arity, 10, 1),
    nn.ReLU(),
    nn.Conv2d(10, 10, 1),
    nn.ReLU(),
    nn.Conv2d(10, 1, 1)
)



m = Conv2dLayerWithComplexNeurons([inner_net_1, inner_net_2, inner_net_3], arity, 16, 33, 3, stride=2)
input = torch.randn(20, 16, 50, 100)
output = m(input)

print(output[0].size())
# for i,v in enumerate(output):
#     print(i, v)
# Out:
# torch.Size([20, 33, 24, 49])

# %%
inner_net_1 = nn.Sequential(
    nn.Linear(arity, 10),
    nn.ReLU(),
    nn.Linear(10, 10),
    nn.ReLU(),
    nn.Linear(10, 1)
)

inner_net_2 = nn.Sequential(
    nn.Linear(arity, 10),
    nn.ReLU(),
    nn.Linear(10, 10),
    nn.ReLU(),
    nn.Linear(10, 1)
)

inner_net_3 = nn.Sequential(
    nn.Linear(arity, 10),
    nn.ReLU(),
    nn.Linear(10, 10),
    nn.ReLU(),
    nn.Linear(10, 1)
)

outer_net_1 = DenseLayerWithComplexNeurons([inner_net_1, inner_net_2, inner_net_3], arity, 16, 9)
outer_net_2 = DenseLayerWithComplexNeurons([inner_net_1, inner_net_2, inner_net_3], arity, 9, 3)
input = torch.randn(128, 16)
output = outer_net_1(input)
output = outer_net_2(output)
print(output[0].size())
# Out:
# 2
